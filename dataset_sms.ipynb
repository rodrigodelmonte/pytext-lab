# %%
import pandas as pd

# %%
df = pd.read_table('./dataset/SMSSpamCollection')
df.columns = ['category', 'text']

# %%
df.describe()
# Out:
#        category                    text
# count      5571                    5571
# unique        2                    5168
# top         ham  Sorry, I'll call later
# freq       4824                      30

# %%
df['category'].describe()
# Out:
# count     5571
# unique       2
# top        ham
# freq      4824
# Name: category, dtype: object

# %%
df.sample(30)
# Out:
#      category                                               text
# 2649      ham  You might want to pull out more just in case a...
# 4225      ham  The world suffers a lot... Not because of the ...
# 3778      ham  Once a fishrman woke early in d mrng. It was v...
# 394       ham  Pick you up bout 7.30ish? What time are  and t...
# 2975      ham      Don't worry, * is easy once have ingredients!
# 2015      ham  Just re read it and I have no shame but tell m...
# 1274      ham  Let me know how to contact you. I've you settl...
# 2849     spam  YOUR CHANCE TO BE ON A REALITY FANTASY SHOW ca...
# 2690     spam  sports fans - get the latest sports news str* ...
# 1845      ham  Hi. || Do u want | to join me with sts later? ...
# 4022      ham  U gd lor go shopping i got stuff to do. U wan ...
# 298       ham  I cant pick the phone right now. Pls send a me...
# 3671      ham                      Yup. Thk of u oso boring wat.
# ...

# %%
train_df = df.loc[:4449]

# %%
test_df = df.loc[4500:]

# %%
train_df.to_csv('./dataset/smsspam_train.tsv', sep='\t', header=0, index=False)

# %%
test_df.to_csv('./dataset/smsspam_test.tsv', sep='\t', header=0, index=False)
